# %%
import tensorflow as tf

# %%
m = tf.constant(77,dtype="int32",name="mul1")
n = tf.constant(34,dtype="int32",name="mul2")
new_output= tf.multiply(m,n)
print(new_output)
# Out:
# tf.Tensor(2618, shape=(), dtype=int32)

# %%
a = tf.Variable([[14, 23],[34, 67]])
b = tf.Variable([[25, 78],[89, 178]])
new_output= tf.add(a,b)
print(new_output)
# Out:
# tf.Tensor(
# [[ 39 101]
#  [123 245]], shape=(2, 2), dtype=int32)

# %%
# Import necessary libraries
import numpy as np
import pandas as pd

#Create a dictionary which has names of the patients, their ages, and the diseases
data_dict={
"Patient":["Raju", "Ramu", "Nitin", "Suraj","Kunal","Kushal","Anyy","Messi","Jonas","Xavier"],
"Age":[44,71,67,8,56,12,31,3,np.nan,17],
"Gender":[np.nan,np.nan,np.nan,np.nan,np.nan,"Male","Male",np.nan,np.nan,np.nan],
"Diesease":[np.nan ,"Heart Attack","Cancer",np.nan,"Heart Attack","Brain Stroke","Acidity", np.nan,"Brain Stroke","Skin Cancer"],
}

#Create a DataFrame using Pandas
Patients_data=pd.DataFrame(data_dict)
Patients_data
# Out:
#   Patient   Age Gender      Diesease
# 0    Raju  44.0    NaN           NaN
# 1    Ramu  71.0    NaN  Heart Attack
# 2   Nitin  67.0    NaN        Cancer
# 3   Suraj   8.0    NaN           NaN
# 4   Kunal  56.0    NaN  Heart Attack
# 5  Kushal  12.0   Male  Brain Stroke
# 6    Anyy  31.0   Male       Acidity
# 7   Messi   3.0    NaN           NaN
# 8   Jonas   NaN    NaN  Brain Stroke
# 9  Xavier  17.0    NaN   Skin Cancer

# %%
# Drop the rows that have NaN or missing value in the DataFrame based on the threshold
Patients_data.dropna(thresh=4)
# Out:
#   Patient   Age Gender      Diesease
# 5  Kushal  12.0   Male  Brain Stroke
# 6    Anyy  31.0   Male       Acidity

# %%
Employee_Age=[31,23,42,53,29,43,51,33,29,30]

# %%
Patients_data["Team"]=Employee_Age
Patients_data
# Out:
#   Patient  Age Gender      Diesease  Team
# 0    Raju   31    NaN           NaN    31
# 1    Ramu   23    NaN  Heart Attack    23
# 2   Nitin   42    NaN        Cancer    42
# 3   Suraj   53    NaN           NaN    53
# 4   Kunal   29    NaN  Heart Attack    29
# 5  Kushal   43   Male  Brain Stroke    43
# 6    Anyy   51   Male       Acidity    51
# 7   Messi   33    NaN           NaN    33
# 8   Jonas   29    NaN  Brain Stroke    29
# 9  Xavier   30    NaN   Skin Cancer    30

# %%
Patients_data.insert(4,"Video",[12,55,44,88,21,66,44,14,42,77])
Patients_data
# Out:
#   Patient  Age Gender      Diesease  Video  Car  Team
# 0    Raju   31    NaN           NaN     12   12    31
# 1    Ramu   23    NaN  Heart Attack     55   55    23
# 2   Nitin   42    NaN        Cancer     44   44    42
# 3   Suraj   53    NaN           NaN     88   88    53
# 4   Kunal   29    NaN  Heart Attack     21   21    29
# 5  Kushal   43   Male  Brain Stroke     66   66    43
# 6    Anyy   51   Male       Acidity     44   44    51
# 7   Messi   33    NaN           NaN     14   14    33
# 8   Jonas   29    NaN  Brain Stroke     42   42    29
# 9  Xavier   30    NaN   Skin Cancer     77   77    30
